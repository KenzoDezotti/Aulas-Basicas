# %%
#importação dos pacotes basicos do python para abrir cvs e manipular dados
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

from pathlib import Path

# %config Completer.use_jedi = False

# %%
google = pd.read_csv("/home/kenzo/Desktop/GOOG.csv")

# %%
google.plot()
# Out:
# <AxesSubplot:>

# %%
google["Open"].plot()
# Out:
# <AxesSubplot:>

# %%
google.plot(x="Date", y="Open")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
google.plot.box()
# Out:
# <AxesSubplot:>

# %%
google.plot.area(figsize=(12, 4), subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
bruna = pd.read_csv('/home/kenzo/Documents/hosp cancer/bruna arquivos mestrado/Array metilação/clinical_data.txt')

# %%
bruna
# Out:
#    sample_name\tsentrix_id\tsentrix_position\tbarcode\tage\tgender\tstage\tstage_groups\tanatomic_site\trecurrence\tsurvival_status\tsurvival_years\tchemo_radio\ttobacco_status \ttobacco\talcohol_status\talcohol\t\t
# 0   2\t201508130036\tR02C01\t201508130036_R02C01\t...
# 1   4\t201508130036\tR04C01\t201508130036_R04C01\t...
# 2   6\t201508130036\tR06C01\t201508130036_R06C01\t...
# 3   12\t201508130036\tR08C01\t201508130036_R08C01\...
# 4   14\t201508130053\tR01C01\t201508130053_R01C01\...
# 5   15\t201508130053\tR03C01\t201508130053_R03C01\...
# 6   22\t201508130038\tR06C01\t201508130038_R06C01\...
# 7   26\t201508130024\tR01C01\t201508130024_R01C01\...
# 8   28\t201508130024\tR05C01\t201508130024_R05C01\...
# 9   19\t201508130053\tR07C01\t201508130053_R07C01\...
# 10  18\t201508130053\tR05C01\t201508130053_R05C01\...
# 11  20\t201508130038\tR02C01\t201508130038_R02C01\...
# 12  21\t201508130038\tR04C01\t201508130038_R04C01\...
# ...

# %%
bruna.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_14137/21629032.py in <module>
# ----> 1 bruna.plot()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     284     def generate(self):
# ...
